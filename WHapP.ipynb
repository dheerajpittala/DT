# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('happiness.csv')

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %% [markdown]
# # Exploratory Data Analysis EDA

# %%
df.shape
# Out:
# (158, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
# Country                          158 non-null object
# Region                           158 non-null object
# Happiness Rank                   158 non-null int64
# Happiness Score                  158 non-null float64
# Standard Error                   158 non-null float64
# Economy (GDP per Capita)         158 non-null float64
# Family                           158 non-null float64
# Health (Life Expectancy)         158 non-null float64
# Freedom                          158 non-null float64
# Trust (Government Corruption)    158 non-null float64
# Generosity                       158 non-null float64
# Dystopia Residual                158 non-null float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# # Summary Statistics

# %%
#Summary Statistics
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# 50%                    0.910245    1.029510                  0.696705
# 75%                    1.158448    1.214405                  0.811013
# max                    1.690420    1.402230                  1.025250
#
#           Freedom  Trust (Government Corruption)  Generosity  \
# count  158.000000                     158.000000  158.000000
# mean     0.428615                       0.143422    0.237296
# std      0.150693                       0.120034    0.126685
# min      0.000000                       0.000000    0.000000
# 25%      0.328330                       0.061675    0.150553
# 50%      0.435515                       0.107220    0.216130
# 75%      0.549092                       0.180255    0.309883
# max      0.669730                       0.551910    0.795880
#
#        Dystopia Residual
# count         158.000000
# mean            2.098977
# std             0.553550
# min             0.328580
# 25%             1.759410
# 50%             2.095415
# 75%             2.462415
# max             3.602140

# %%
df['Region'].unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
df['Region'].value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# Australia and New Zealand           2
# North America                       2
# Name: Region, dtype: int64

# %% [markdown]
# # Data Visualization

# %% [markdown]
# Correlation with or without filling numerical values

# %%
dfcor=df.corr()
dfcor
sns.heatmap(dfcor)
sns.color_palette?
sns.heatmap?
plt.figure(figsize=(6,4))
sns.heatmap(dfcor,cmap='Blues',annot=True)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# # Ploting Outliers by Box Plot

# %% [markdown]
# # Univariate Analysis

# %%
df['Happiness Rank'].plot.box()

# %% [markdown]
# No outliers present in Happiness Rank column.

# %%
df['Happiness Score'].plot.box()

# %% [markdown]
# No outliers present in Happiness Score column.

# %%
df['Standard Error'].plot.box()

# %% [markdown]
# Outliers is present in Standard Error column

# %%
df['Economy (GDP per Capita)'].plot.box()

# %% [markdown]
# No outliers present in Economy(GDP per Capita) column.

# %%
df['Family'].plot.box()

# %% [markdown]
# Outliers present in Family column

# %%
df['Health (Life Expectancy)'].plot.box()

# %% [markdown]
# No outliers present in Health(Life Expectancy) column.

# %%
df['Freedom'].plot.box()

# %% [markdown]
# No outliers present in Freedom column.

# %%
df['Trust (Government Corruption)'].plot.box()

# %% [markdown]
# Trust (Government Corruption) column has outlier

# %%
df['Generosity'].plot.box()

# %% [markdown]
# Generosity has outlier

# %%
df['Dystopia Residual'].plot.box()

# %% [markdown]
# Dystopia Residual has outliers

# %% [markdown]
# # Bivariate Analysis

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
plt.scatter(df['Happiness Rank'],df['Happiness Score'])
plt.show()

# %% [markdown]
# With help of scatter plot we are getting relation between HAPPINESS RANK and HAPPINESS SCORE and it is showing negative relation.

# %%
plt.scatter(df['Happiness Score'],df['Family'])
plt.show()

# %% [markdown]
# With help of scatter plot we are getting relation between HAPPINESS RANK and FAMILY and it is showing positive relation.

# %%
plt.scatter(df['Happiness Score'],df['Economy (GDP per Capita)'])
plt.show()

# %% [markdown]
# With help of scatter plot we are getting relation between Happiness Score and Economy (GDP per Capita) is quite good relation.

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
dX = df[['Happiness Rank', 'Happiness Score',
       'Standard Error', 'Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
       'Generosity', 'Dystopia Residual']]

# %% [markdown]
# Removing two categorical columns from final data and storing in "dX" vairiable.

# %% [markdown]
# # Multivariate Anaysis

# %%
collist=dX.columns.values
ncol=10
nrows=10

# %%
plt.figure(figsize=(ncol,5*ncol))
for i in range(1,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(dX[collist[i]],color='green', orient='v')
    plt.tight_layout()

# %% [markdown]
# Ploting all columns by Boxplot to find outliers in a one diagram.

# %% [markdown]
# # Distribution of Skewness

# %%
sns.distplot(df['Happiness Rank'])

# %% [markdown]
# In Happiness Rank all data Normaly Distributed. It is a symetrical data and also in Bell Shape Curve.

# %%
sns.distplot(df['Happiness Score'])

# %% [markdown]
# In Happiness Score data Normally Distributed.

# %%
sns.distplot(df['Standard Error'])

# %% [markdown]
# The data not normally distributed and it is left trail skewness.

# %%
sns.distplot(df['Economy (GDP per Capita)'])

# %% [markdown]
# The data normally distributed and it is a symetrical data.

# %%
sns.distplot(df['Family'])

# %% [markdown]
# The data not normally distributed and it is right trail skewness.

# %%
sns.distplot(df['Health (Life Expectancy)'])

# %% [markdown]
# Data not normally distributed and also in not bell shape curve.

# %%
sns.distplot(df['Freedom'])

# %% [markdown]
# In Freedom column all data is normally distributed and also in bell shape curve.

# %%
sns.distplot(df['Trust (Government Corruption)'])

# %% [markdown]
# Data is not normally distributed. It is Left trail skewness.

# %%
sns.distplot(df['Generosity'])

# %% [markdown]
# The data is not normally distributed.

# %%
sns.distplot(df['Dystopia Residual'])

# %% [markdown]
# the data is normally distributed and also in bell shape curve.

# %%
plt.figure(figsize=(16,16))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol, i+1)
    sns.distplot(df[collist[i]])

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
df['Standard Error']=np.log(df['Standard Error'])
df['Standard Error'].plot.hist()

# %%
sns.pairplot(df)

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
df['Region'] = labelencoder.fit_transform(df['Region'])
df.head(10)
# Out:
#        Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0  Switzerland       9               1            7.587       -3.378165
# 1      Iceland       9               2            7.561       -3.019206
# 2      Denmark       9               3            7.527       -3.402799
# 3       Norway       9               4            7.522       -3.249335
# 4       Canada       5               5            7.427       -3.337378
# 5      Finland       9               6            7.406       -3.460947
# 6  Netherlands       9               7            7.378       -3.575908
# 7       Sweden       9               8            7.364       -3.455548
# 8  New Zealand       0               9            7.286       -3.389961
# 9    Australia       0              10            7.284       -3.198338
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
# 5                   1.29025  1.31826                   0.88911  0.64169
# 6                   1.32944  1.28017                   0.89284  0.61576
# 7                   1.33171  1.28907                   0.91087  0.65980
# 8                   1.25018  1.31967                   0.90837  0.63938
# 9                   1.33358  1.30923                   0.93156  0.65124
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.41978     0.29678            2.51738
# 1                        0.14145     0.43630            2.70201
# 2                        0.48357     0.34139            2.49204
# 3                        0.36503     0.34699            2.46531
# 4                        0.32957     0.45811            2.45176
# 5                        0.41372     0.23351            2.61955
# 6                        0.31814     0.47610            2.46570
# 7                        0.43844     0.36262            2.37119
# 8                        0.42922     0.47501            2.26425
# 9                        0.35637     0.43562            2.26646

# %% [markdown]
# Use LabelEncoder for categorical data

# %%
df.dtypes
# Out:
# Country                           object
# Region                             int32
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df['Region']=df['Region'].astype(float,errors='raise')
df['Happiness Rank']=df['Happiness Rank'].astype(float,errors='raise')

# %%
df.dtypes
# Out:
# Country                           object
# Region                           float64
# Happiness Rank                   float64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df_final = df[['Region', 'Happiness Rank', 'Happiness Score',
       'Standard Error', 'Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
       'Generosity', 'Dystopia Residual']]

# %% [markdown]
# Droping Categorical columns from main data for collecting numerical data.

# %%
df_final.dtypes
# Out:
# Region                           float64
# Happiness Rank                   float64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# # ZSCORE VALUE

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df_final))
z
# Out:
# array([[1.30025593, 1.72099989, 1.93736005, ..., 2.30965159, 0.47103971,
#         0.75825809],
#        [1.30025593, 1.69907456, 1.91458063, ..., 0.01647953, 1.57585637,
#         1.09285682],
#        [1.30025593, 1.67714922, 1.88479215, ..., 2.8427738 , 0.8242928 ,
#         0.71233526],
#        ...,
#        [0.37544095, 1.67742676, 2.0761992 , ..., 0.38141902, 1.85689094,
#         3.20843049],
#        [0.96511655, 1.69935209, 2.1646885 , ..., 0.35771452, 0.31694987,
#         0.48198451],
#        [0.96511655, 1.72127743, 2.22251319, ..., 0.30180313, 0.5581534 ,
#         0.96361241]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27,  64, 128, 147, 153, 155, 157], dtype=int64), array([ 8,  3,  9,  5,  8, 10,  5], dtype=int64))

# %%
df_final_new=df_final[(z<3).all(axis=1)]
df_final_new
# Out:
#      Region  Happiness Rank  Happiness Score  Standard Error  \
# 0       9.0             1.0            7.587       -3.378165
# 1       9.0             2.0            7.561       -3.019206
# 2       9.0             3.0            7.527       -3.402799
# 3       9.0             4.0            7.522       -3.249335
# 4       5.0             5.0            7.427       -3.337378
# ..      ...             ...              ...             ...
# 150     8.0           151.0            3.655       -2.967923
# 151     8.0           152.0            3.587       -3.140989
# 152     7.0           153.0            3.575       -3.478943
# 154     8.0           155.0            3.340       -3.308801
# 156     8.0           157.0            2.905       -2.446686
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 150                   0.46534  0.77115                   0.15185  0.46866
# 151                   0.25812  0.85188                   0.27125  0.39493
# 152                   0.31982  0.30285                   0.30335  0.23414
# 154                   0.28665  0.35386                   0.31910  0.48450
# 156                   0.01530  0.41587                   0.22396  0.11850
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                          0.41978     0.29678            2.51738
# 1                          0.14145     0.43630            2.70201
# 2                          0.48357     0.34139            2.49204
# 3                          0.36503     0.34699            2.46531
# 4                          0.32957     0.45811            2.45176
# ..                             ...         ...                ...
# 150                        0.17922     0.20165            1.41723
# 151                        0.12832     0.21747            1.46494
# 152                        0.09719     0.36510            1.95210
# 154                        0.08010     0.18260            1.63328
# 156                        0.10062     0.19727            1.83302
#
# [151 rows x 11 columns]

# %%
print(df.shape)
print(df_final_new.shape)
# Out:
# (158, 12)
# (151, 11)

# %% [markdown]
# # Percentage Data Loss

# %%
loss_percent=(158-151)/158*100
print(loss_percent)
# Out:
# 4.430379746835443

# %%
#checking whether outliers are still there
df_final_new.skew()
# Out:
# Region                          -0.097966
# Happiness Rank                   0.003011
# Happiness Score                  0.170109
# Standard Error                   0.341173
# Economy (GDP per Capita)        -0.402358
# Family                          -0.805183
# Health (Life Expectancy)        -0.727308
# Freedom                         -0.396610
# Trust (Government Corruption)    1.283142
# Generosity                       0.641370
# Dystopia Residual               -0.038429
# dtype: float64

# %%
df_final_new.columns
# Out:
# Index(['Region', 'Happiness Rank', 'Happiness Score', 'Standard Error',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
x=df_final_new[['Region', 'Happiness Rank', 'Standard Error',
       'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
       'Freedom', 'Trust (Government Corruption)', 'Generosity',
       'Dystopia Residual']]
x.shape
# Out:
# (151, 10)

# %%
y= df_final_new['Happiness Score']
y.head()
# Out:
# 0    7.587
# 1    7.561
# 2    7.527
# 3    7.522
# 4    7.427
# Name: Happiness Score, dtype: float64

# %%
y.shape
# Out:
# (151,)

# %% [markdown]
# Spliting the all data into x and y for model building.

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=42)

# %%
x_train.shape
# Out:
# (101, 10)

# %%
x_test.shape
# Out:
# (50, 10)

# %%
y_train.shape
# Out:
# (101,)

# %%
y_test.shape
# Out:
# (50,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
from sklearn.tree import DecisionTreeRegressor 
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # Model Building

# %% [markdown]
# # Linear Regression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.coef_
# Out:
# array([-2.01251898e-05, -7.64441759e-06, -4.41351123e-05,  9.99930619e-01,
#         9.99664268e-01,  9.99117181e-01,  9.99326733e-01,  1.00005627e+00,
#         9.99879508e-01,  9.99673165e-01])

# %%
lr.intercept_
# Out:
# 0.0024966683600871065

# %%
lr.score(x_train,y_train)
# Out:
# 0.9999999319823591

# %%
pred=lr.predict(x_test)
print('Predicted Result Price:',pred)
print('Actual Price,y_test')
# Out:
# Predicted Result Price: [5.25289987 6.9371962  5.12889265 5.14039356 3.6808218  6.47671272
#  5.19377543 5.68854693 5.82826332 5.10149544 5.98374096 7.19962911
#  6.298163   7.28405526 6.90142043 3.93077714 4.56464671 3.65519416
#  5.82407237 4.03311616 6.50502841 5.1231425  6.66961862 4.07676988
#  4.34993579 3.78078664 4.6333833  5.54837279 4.86724531 6.48513284
#  6.81012834 6.98253447 4.33225144 7.22552061 4.2923755  5.87834816
#  5.58866355 6.57489857 4.71474418 7.42684542 6.454619   6.00291227
#  3.66728659 3.34008891 6.94617346 7.27752427 4.67736286 4.29675798
#  5.26808178 4.57127842]
# Actual Price,y_test

# %%
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred))
print('Mean squared error:',mean_squared_error(y_test,pred))
print('Root Mean Squared error:',np.sqrt(mean_squared_error(y_test,pred)))
print(r2_score(y_test,pred))
# Out:
# error:
# Mean absolute error: 0.0002497008974614978
# Mean squared error: 7.9173721340888e-08
# Root Mean Squared error: 0.0002813782531413684
# 0.9999999424076406

# %% [markdown]
# Linear Regression Algorithm performing very good and the score is 99%.

# %% [markdown]
# # Random Forest Regressor

# %%
rf=RandomForestRegressor(n_estimators=100,random_state=42)
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=100,
#                       n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                       warm_start=False)

# %%
rf.score(x_train,y_train)
# Out:
# 0.998838966474461

# %%
pred=rf.predict(x_test)
print('Predicted Result Price:',pred)
print('Actual Price,y_test')
# Out:
# Predicted Result Price: [5.2552  6.89131 5.17021 5.20693 3.82335 6.36303 5.20442 5.67838 5.83421
#  5.1094  5.97331 7.25377 6.28043 7.32216 6.89777 3.91868 4.55054 3.62999
#  5.81569 3.98546 6.52271 5.11309 6.78074 4.19258 4.4083  3.91089 4.61553
#  5.48238 4.8721  6.5034  6.806   7.08984 4.37045 7.17884 4.14282 5.87445
#  5.56352 6.67916 4.72396 7.38309 6.32582 6.12267 3.63022 3.5334  7.01595
#  7.24725 4.68245 4.19907 5.29486 4.56719]
# Actual Price,y_test

# %%
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred))
print('Mean squared error:',mean_squared_error(y_test,pred))
print('Root Mean Squared error:',np.sqrt(mean_squared_error(y_test,pred)))
print(r2_score(y_test,pred))
# Out:
# error:
# Mean absolute error: 0.04944500000000012
# Mean squared error: 0.004761612665999984
# Root Mean Squared error: 0.06900443946587773
# 0.9965363190764827

# %% [markdown]
# Random Forest Regressor Algorithm performing very good and the score is 99%.

# %% [markdown]
# # Decision Tree Regressor

# %%
dtc=DecisionTreeRegressor()
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
pred=dtc.predict(x_test)
print('Predicted Result Price:',pred)
print('Actual Price,y_test')
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred))
print('Mean squared error:',mean_squared_error(y_test,pred))
print('Root Mean Squared error:',np.sqrt(mean_squared_error(y_test,pred)))
print(r2_score(y_test,pred))
# Out:
# Predicted Result Price: [5.192 6.867 5.098 5.212 3.904 6.295 5.192 5.695 5.833 5.124 5.96  7.119
#  6.295 7.286 6.853 3.995 4.55  3.587 5.759 3.995 6.786 5.124 6.786 4.252
#  4.271 3.904 4.61  5.399 4.874 6.75  6.574 7.187 4.194 7.187 4.369 5.848
#  5.605 6.786 4.681 7.527 6.295 6.168 3.587 3.587 6.867 7.119 4.686 4.369
#  5.286 4.61 ]
# Actual Price,y_test
# error:
# Mean absolute error: 0.08828
# Mean squared error: 0.013983160000000001
# Root Mean Squared error: 0.11825041226143782
# 0.9898284031189001

# %% [markdown]
# Decision Tree Regressor Algorithm performing very good and the score is 98%.

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %% [markdown]
# As we know after deployment all algorithms they are performing very well but there may be Overfiting and underfiting case. Remove Overfiting and UnderFiting we have to cross validate all algorithms.

# %%
from sklearn.linear_model import ElasticNet

# %%
Enr=ElasticNet(alpha=0.0001)
Enr.fit(x_train,y_train)
Enrpred=Enr.predict(x_test)
print(Enr.score(x_train,y_train))
Enr.coef_
# Out:
# 0.9999724842701632
# array([ 6.37530721e-04, -1.13870421e-03, -4.59199293e-03,  9.57681553e-01,
#         9.53340824e-01,  9.44827472e-01,  9.52623941e-01,  9.57892043e-01,
#         9.55398059e-01,  9.53580947e-01])

# %%
print(cross_val_score(rf,x,y,cv=5).mean())
# Out:
# -1.695194608983424

# %%
dtcscore=cross_val_score(dtc,x,y,cv=5)
print(dtcscore)
print(dtcscore.mean(),dtcscore.std())
# Out:
# [-3.14215191 -0.31319973 -0.25329615 -0.34825473 -2.496502  ]
# -1.3106809045298466 1.248979829046524

# %% [markdown]
# # Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn import datasets, linear_model
model = linear_model.LinearRegression()
parameters = {'fit_intercept':[True,False], 'normalize':[True,False], 'copy_X':[True, False]}
grid = GridSearchCV(model,parameters, cv=None)
grid.fit(x_train, y_train)
print ("r2 / variance : ", grid.best_score_)
print("Residual sum of squares: %.2f" % np.mean((grid.predict(x_test) - y_test) ** 2))
# Out:
# r2 / variance :  0.9999999046152073
# Residual sum of squares: 0.00

# %% [markdown]
# After hyper parameter tuining by GridSearchCV we find Liner Regression Algorithm showing highest score.

# %% [markdown]
# # Saving Model

# %%
import pickle
filename = 'WHP_practice.pkl'
pickle.dump(lr, open(filename,'wb'))

# %% [markdown]
# # Conclusion

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(lr.predict(x_test))
df_com=pd.DataFrame({'Original':a,'Predicted':predicted},index=range(len(a)))
df_com
# Out:
#     Original  Predicted
# 0      5.253   5.252900
# 1      6.937   6.937196
# 2      5.129   5.128893
# 3      5.140   5.140394
# 4      3.681   3.680822
# 5      6.477   6.476713
# 6      5.194   5.193775
# 7      5.689   5.688547
# 8      5.828   5.828263
# 9      5.102   5.101495
# 10     5.984   5.983741
# 11     7.200   7.199629
# 12     6.298   6.298163
# 13     7.284   7.284055
# 14     6.901   6.901420
# 15     3.931   3.930777
# 16     4.565   4.564647
# 17     3.655   3.655194
# 18     5.824   5.824072
# 19     4.033   4.033116
# 20     6.505   6.505028
# 21     5.123   5.123142
# 22     6.670   6.669619
# 23     4.077   4.076770
# 24     4.350   4.349936
# 25     3.781   3.780787
# 26     4.633   4.633383
# 27     5.548   5.548373
# 28     4.867   4.867245
# 29     6.485   6.485133
# 30     6.810   6.810128
# 31     6.983   6.982534
# 32     4.332   4.332251
# 33     7.226   7.225521
# 34     4.292   4.292375
# 35     5.878   5.878348
# 36     5.589   5.588664
# 37     6.575   6.574899
# 38     4.715   4.714744
# 39     7.427   7.426845
# 40     6.455   6.454619
# 41     6.003   6.002912
# 42     3.667   3.667287
# 43     3.340   3.340089
# 44     6.946   6.946173
# 45     7.278   7.277524
# 46     4.677   4.677363
# 47     4.297   4.296758
# 48     5.268   5.268082
# 49     4.571   4.571278
